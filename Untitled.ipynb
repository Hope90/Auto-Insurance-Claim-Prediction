# %% [markdown]
# <div style="text-align: center"> Descartes Underwriting R&D Data Scientist Technical Test</div>
# <div style="text-align: center"> Candidate: Xi WEI</div>

# %% [markdown]
# # <font color=blue>Project Description</font>
#
# -> Project Name: Auto Insurance
#
# -> Goal: To make a prediction on the "TARGET_FLAG", e.g. to predict the claims to the insurance company.
#
# -> Processes:
# + Data Analysis
# + Data Pre-processing
# + Modeling
# + Evaluation
#
# -> Project output: prediction.csv

# %% [markdown]
# # Data Analysis
# ## Import the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
#Remove warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import the Dataset
# **Import Train and Test Datasets**

# %%
train = pd.read_csv("train_auto.csv")
display(train.head())
print(train.info())
# Out:
#    INDEX  TARGET_FLAG  TARGET_AMT  KIDSDRIV   AGE  HOMEKIDS   YOJ    INCOME  \
# 0      1            0         0.0         0  60.0         0  11.0   $67,349
# 1      2            0         0.0         0  43.0         0  11.0   $91,449
# 2      4            0         0.0         0  35.0         1  10.0   $16,039
# 3      5            0         0.0         0  51.0         0  14.0       NaN
# 4      6            0         0.0         0  50.0         0   NaN  $114,986
#
#   PARENT1  HOME_VAL  ... BLUEBOOK TIF CAR_TYPE RED_CAR  OLDCLAIM CLM_FREQ  \
# 0      No        $0  ...  $14,230  11  Minivan     yes    $4,461        2
# 1      No  $257,252  ...  $14,940   1  Minivan     yes        $0        0
# 2      No  $124,191  ...   $4,010   4    z_SUV      no   $38,690        2
# 3      No  $306,251  ...  $15,440   7  Minivan     yes        $0        0
# 4      No  $243,925  ...  $18,000   1    z_SUV      no   $19,217        2
#
#   REVOKED  MVR_PTS CAR_AGE           URBANICITY
# ...

# %%
test = pd.read_csv("test_auto.csv")
display(test.head())
print(test.info())
# Out:
#    INDEX  TARGET_FLAG  TARGET_AMT  KIDSDRIV   AGE  HOMEKIDS   YOJ   INCOME  \
# 0      3          NaN         NaN         0  48.0         0  11.0  $52,881
# 1      9          NaN         NaN         1  40.0         1  11.0  $50,815
# 2     10          NaN         NaN         0  44.0         2  12.0  $43,486
# 3     18          NaN         NaN         0  35.0         2   NaN  $21,204
# 4     21          NaN         NaN         0  59.0         0  12.0  $87,460
#
#   PARENT1 HOME_VAL  ... BLUEBOOK TIF CAR_TYPE RED_CAR  OLDCLAIM CLM_FREQ  \
# 0      No       $0  ...  $21,970   1      Van     yes        $0        0
# 1     Yes       $0  ...  $18,930   6  Minivan      no    $3,295        1
# 2     Yes       $0  ...   $5,900  10    z_SUV      no        $0        0
# 3     Yes       $0  ...   $9,230   6   Pickup      no        $0        0
# 4      No       $0  ...  $15,420   1  Minivan     yes   $44,857        2
#
#   REVOKED  MVR_PTS CAR_AGE             URBANICITY
# ...

# %% [markdown]
# <font color=blue>1. Train dataset is a data frame of 8161 rows * 26 columns, while test dataset is a 2141 rows * 26 columns data frame.</font>
# <font color=blue>2. The prediction “TARGET_FLAG” is a binary variable. Value "1" represents "claim" while value "0" represents "not-claim". Therefore, for predicting a binary variable, I will use Classification in Machine Learning. </font>
# <font color=blue>3. There is no missing value (NaN) in prediction variable “TARGET_FLAG” in the train dataset. However, there are some missing values in feature variables in the train dataset. Therefore, I will check the missing values and outliers of feature variables before checking the distribution of prediction variable in the train dataset.</font>

# %% [markdown]
# **Data Exploration and Cleaning**

# %%
print(f"There are {len(train.loc[train.isna().any(1)])} rows containing missing values in the train dataset, accounting for {len(train.loc[train.isna().any(1)]) / len(train)* 100:.1f}% of the total rows in the train dataset.")
# Out:
# There are 2116 rows containing missing values in the train dataset, accounting for 25.9% of the total rows in the train dataset.

# %% [markdown]
# <font color=blue>Although the missing-value rows account for around 1/4 of the total rows in the train dataset, those missing-value rows are going to be deleted considering that there are still more than 1000 rows left after deletion.</font>

# %%
train = train.dropna(axis=0)

# %% [markdown]
# **Check the Target Distribution**

# %%
print('Category counts: \n', df_train['TARGET_FLAG'].value_counts())

print(f"There are {df_train.TARGET_FLAG.sum()} positive records and {(1-df_train.TARGET_FLAG).sum()} negative ones")
print(f"That represents {df_train.TARGET_FLAG.sum() / len(df_train)* 100:.2f}% positive classes")

# %% [markdown]
# **Check the Outliers and Missing values**

# %%
print("Train Dataset:\n",train.describe())
print("Test Dataset:\n",test.describe())

# %% [markdown]
# ## Variables Analysis
